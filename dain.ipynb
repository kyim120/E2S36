# %%
# !pip install git+https://github.com/Breakthrough/PySceneDetect.git
# !pip install scenedetect
# !pip install scenedetect
# !pip install deepface
# !pip install torch torchvision torchaudio
# !pip install transformers
# !pip install opencv-python-headless
# !pip install ultralytics
# !pip install matplotlib
# !pip install fastapi uvicorn python-multipart pyngrok nest-asyncio
# !pip install torch transformers ultralytics deepface
# !apt-get install -y libgl1-mesa-glx
# Out:
# ...
#   Cloning https://github.com/Breakthrough/PySceneDetect.git to /tmp/pip-req-build-drz90ydv
#   Running command git clone --filter=blob:none --quiet https://github.com/Breakthrough/PySceneDetect.git /tmp/pip-req-build-drz90ydv
#   Resolved https://github.com/Breakthrough/PySceneDetect.git to commit 287b54864efe1250a970bc24fa15684a7f46b5a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scenedetect: filename=scenedetect-0.7.dev0-py3-none-any.whl size=121250 sha256=66aad1a5832b4ad88223337911073905ca445220adc006f97c35f46ebe2fb028
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z4oerwhs/wheels/77/81/09/0f63e36523a06282950d86791e50c64e06a36e56c2f52598de
# Successfully built scenedetect
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.3/128.3 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 8.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/NLP Project.zip"
extract_path = "/content/drive/MyDrive/Project"

# Create target folder if not exists
os.makedirs(extract_path, exist_ok=True)

# Unzip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Project unzipped to:", extract_path)
# Out:
# ✅ Project unzipped to: /content/drive/MyDrive/Project

# %%
# !ls "/content/drive/MyDrive/Project"
# Out:
# 'NLP Project'

# %%
# !pip install git+https://github.com/Breakthrough/PySceneDetect.git
# !pip install scenedetect deepface torch torchvision torchaudio transformers opencv-python-headless ultralytics matplotlib fastapi uvicorn python-multipart pyngrok nest-asyncio
# !apt-get install -y libgl1-mesa-glx
# Out:
# ...
#   Cloning https://github.com/Breakthrough/PySceneDetect.git to /tmp/pip-req-build-ze14pk51
#   Running command git clone --filter=blob:none --quiet https://github.com/Breakthrough/PySceneDetect.git /tmp/pip-req-build-ze14pk51
#   Resolved https://github.com/Breakthrough/PySceneDetect.git to commit 287b54864efe1250a970bc24fa15684a7f46b5a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# !ls "{drive_path}/static"
# Out:
# ls: cannot access '{drive_path}/static': No such file or directory

# %%
# !ls "/content/drive/MyDrive/Project"
# Out:
# 'NLP Project'

# %%
drive_path = "/content/drive/MyDrive/Project/NLP Project/Code/Project"

# %%
from fastapi import FastAPI
from fastapi.staticfiles import StaticFiles
from fastapi.templating import Jinja2Templates

# Create FastAPI app
app = FastAPI()

# Correct project path
drive_path = "/content/drive/MyDrive/Project/NLP Project/Code/Project"

# Mount static files
app.mount("/static", StaticFiles(directory=f"{drive_path}/static"), name="static")

# Set template directory (where index.html is)
templates = Jinja2Templates(directory=drive_path)

# %%
app.mount("/static", StaticFiles(directory=f"{drive_path}/static"), name="static")
templates = Jinja2Templates(directory=drive_path)

# %%
from fastapi import Request
from fastapi.responses import HTMLResponse
from fastapi.templating import Jinja2Templates

@app.get("/", response_class=HTMLResponse)
async def read_root(request: Request):
    return templates.TemplateResponse("index.html", {"request": request})

# %%
# !ngrok config add-authtoken 33CkonDEthhmYxaMttQ5iCrBlS3_3Rs5hXMCgDBwLLgyzufYo
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import nest_asyncio
import uvicorn
from pyngrok import ngrok

def run_server():
    nest_asyncio.apply()
    public_url = ngrok.connect(8000)
    print("🌍 Public URL:", public_url)
    uvicorn.run(app, host="0.0.0.0", port=8000)

run_server()
# Out:
# INFO:     Started server process [12172]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# 🌍 Public URL: NgrokTunnel: "https://a2c40aa580a4.ngrok-free.app" -> "http://localhost:8000"
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [12172]

# %%
# ================== INSTALL (uncomment in Colab) ==================
# !pip install fastapi uvicorn pyngrok nest_asyncio requests torch torchvision transformers ultralytics deepface opencv-python pillow

# ================== IMPORTS ==================
from fastapi import FastAPI, UploadFile, File, Request, HTTPException
from fastapi.staticfiles import StaticFiles
from fastapi.templating import Jinja2Templates
from fastapi.responses import HTMLResponse
from fastapi.middleware.cors import CORSMiddleware
import torch
import requests
import cv2
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
from ultralytics import YOLO
from deepface import DeepFace
import numpy as np
import collections
import os
import shutil
from pathlib import Path
import uvicorn
from pyngrok import ngrok
import nest_asyncio
import threading

# ================== FASTAPI INIT ==================
app = FastAPI()

# Allow CORS for frontend
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# ================== PATHS ==================
drive_path = "/content/drive/MyDrive/Project/NLP Project/Code/Project"
app.mount("/static", StaticFiles(directory=f"{drive_path}/static"), name="static")
templates = Jinja2Templates(directory=drive_path)

# ================== API KEYS ==================
MISTRAL_API_KEY = "8bhvT7fCsMFassdW44g8VUP2YxmaxlLZ"
MISTRAL_API_URL = "https://api.mistral.ai/v1/chat/completions"

# ================== MODELS ==================
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base", torch_dtype=torch.float16
)
blip_device = "cuda" if torch.cuda.is_available() else "cpu"
blip_model.to(blip_device)

yolo_model_large = YOLO("/content/best.pt")
yolo_model_small = YOLO("/content/best.pt")

# Create uploads directory if not exists
os.makedirs(f"{drive_path}/static/uploads", exist_ok=True)

# ================== HELPERS (Mistral) ==================
def call_mistral(messages, temperature=0.7, model="mistral-small-latest"):
    headers = {"Authorization": f"Bearer {MISTRAL_API_KEY}", "Content-Type": "application/json"}
    data = {"model": model, "messages": messages, "temperature": temperature}
    try:
        response = requests.post(MISTRAL_API_URL, headers=headers, json=data)
        result = response.json()
        return result["choices"][0]["message"]["content"].strip()
    except Exception as e:
        print("Mistral API Error:", str(e))
        return "❌ Error from Mistral API."

def get_task_from_prompt(prompt: str):
    system_msg = (
        "You're a strict classifier. ONLY respond with one of the following exact words:\n"
        "image_captioning, scene_description, object_detection, object_counting, "
        "question_answering, emotion_detection, video_summarization, real_time_tracking.\n"
        "No explanation. No extra text."
    )
    return call_mistral(
        [{"role": "system", "content": system_msg}, {"role": "user", "content": prompt}],
        temperature=0,
    ).lower()

def get_small_talk_reply(prompt: str):
    return call_mistral(
        [{"role": "system", "content": "You're a helpful and friendly assistant."},
         {"role": "user", "content": prompt}],
        temperature=0.7
    )

def describe_caption_with_mistral(caption, objects):
    prompt = f"Describe the scene based on the following details:\nCaption: {caption}\nDetected Objects: {', '.join(objects)}"
    return call_mistral([{"role": "user", "content": prompt}], temperature=0.7)

# ================== TASK FUNCTIONS ==================
def caption_image(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = blip_processor(images=image, return_tensors="pt").to(blip_device, torch.float16)
    generated_ids = blip_model.generate(**inputs, max_new_tokens=50)
    return blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()

def detect_objects(image_path):
    results = yolo_model_large(image_path)
    classes = results[0].names
    class_ids = results[0].boxes.cls.tolist()
    detected_objects = list(set(classes[int(cls_id)] for cls_id in class_ids))
    annotated_img = results[0].plot()

    annotated_path = f"{drive_path}/static/uploads/annotated_{Path(image_path).name}"
    Image.fromarray(annotated_img).save(annotated_path)

    return {
        "objects": detected_objects,
        "annotated_image": f"/static/uploads/annotated_{Path(image_path).name}"
    }

def count_objects(image_path):
    results = yolo_model_large(image_path)
    classes = results[0].names
    class_ids = results[0].boxes.cls.tolist()
    count_dict = {}
    for cls_id in class_ids:
        label = classes[int(cls_id)]
        count_dict[label] = count_dict.get(label, 0) + 1
    return count_dict

def detect_emotion_np(image_np):
    try:
        result = DeepFace.analyze(img_path=image_np, actions=["emotion"], enforce_detection=False)
        if isinstance(result, list):
            return [r["dominant_emotion"] for r in result]
        else:
            return [result["dominant_emotion"]]
    except:
        return []

# ================== API ENDPOINTS ==================
@app.post("/upload")
async def upload_file(file: UploadFile = File(...)):
    try:
        file_location = f"{drive_path}/static/uploads/{file.filename}"
        with open(file_location, "wb+") as file_object:
            shutil.copyfileobj(file.file, file_object)

        is_video = file.filename.lower().endswith((".mp4", ".avi", ".mov", ".mkv"))

        if not is_video:
            caption = caption_image(file_location)
            objects = detect_objects(file_location)
        else:
            caption = None
            objects = None

        return {
            "filename": file.filename,
            "filepath": f"/static/uploads/{file.filename}",
            "is_video": is_video,
            "caption": caption,
            "objects": objects,
        }
    except Exception as e:
        raise HTTPException(status_code=500, detail=str(e))

@app.post("/process")
async def process_request(request_data: dict):
    try:
        prompt = request_data.get("prompt", "").strip().lower()
        filepath = request_data.get("filepath", "")
        is_video = request_data.get("is_video", False)
        caption = request_data.get("caption", "")
        objects = request_data.get("objects", [])

        small_talk_phrases = ["hi", "hello", "hey", "yo", "howdy", "sup",
                             "good morning", "good evening", "what's up"]
        if prompt in small_talk_phrases:
            return {
                "response": "🤖 Hey there! 👋\n✨ I can help you with:\n- 🖼️ Captioning\n- 📷 Descriptions\n- 🔍 Detection\n- 🔢 Counting\n- 😊 Emotions\n- ❓ Q&A\n- 🎬 Summarization\n- 🔄 Tracking",
                "type": "small_talk",
            }

        task = get_task_from_prompt(prompt)

        if not task:
            return {
                "response": "🤖 I'm here for anything you need! Try asking me about an image or video task.",
                "type": "info",
            }

        if task in ["real_time_tracking", "video_summarization"] and not is_video:
            return {"response": "❌ This task requires a video file.", "type": "error"}
        elif task in ["image_captioning", "scene_description", "object_detection",
                      "object_counting", "emotion_detection", "question_answering"] and is_video:
            return {"response": "❌ This task requires an image file.", "type": "error"}

        full_path = f"{drive_path}{filepath}"
        result = {}
        if task == "image_captioning":
            result["response"] = f"🖼️ Caption: {caption}"
        elif task == "scene_description":
            description = describe_caption_with_mistral(caption, objects["objects"])
            result["response"] = f"📝 Scene Description: {description}"
        elif task == "object_detection":
            result["response"] = f"📦 Detected Objects: {objects['objects']}"
            result["annotated_image"] = objects["annotated_image"]
        elif task == "object_counting":
            count = count_objects(full_path)
            result["response"] = f"🔢 Object Count: {count}"
        elif task == "emotion_detection":
            img = cv2.imread(full_path)
            emotions = detect_emotion_np(img)
            result["response"] = f"😊 Detected Emotions: {collections.Counter(emotions)}"
        elif task == "question_answering":
            answer = get_small_talk_reply(f"Based on the image caption: '{caption}', answer: {prompt}")
            result["response"] = f"💡 Answer: {answer}"
        elif task == "real_time_tracking":
            result["response"] = "🔄 Real-time tracking not yet integrated."
        elif task == "video_summarization":
            result["response"] = "🎬 Video summarization not yet integrated."

        result["type"] = "task_response"
        return result

    except Exception as e:
        raise HTTPException(status_code=500, detail=str(e))

@app.get("/", response_class=HTMLResponse)
async def serve_frontend(request: Request):
    return templates.TemplateResponse("index.html", {"request": request})

# ================== RUN & STOP SERVER ==================
server_instance = None
thread = None

def run_server():
    global server_instance, thread
    ngrok.set_auth_token("33CkonDEthhmYxaMttQ5iCrBlS3_3Rs5hXMCgDBwLLgyzufYo")
    public_url = ngrok.connect(8000).public_url
    print(f"🚀 FastAPI server is live at: {public_url}")

    nest_asyncio.apply()
    config = uvicorn.Config(app, host="0.0.0.0", port=8000, log_level="info")
    server_instance = uvicorn.Server(config)

    thread = threading.Thread(target=server_instance.run, daemon=True)
    thread.start()

def stop_server():
    global server_instance
    if server_instance:
        server_instance.should_exit = True
        print("🛑 Server stopped.")

# ================== START ==================
# Call run_server() to launch
# Call stop_server() to stop
run_server()   # starts server
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# 🚀 FastAPI server is live at: https://bloodily-unminimising-margorie.ngrok-free.dev
# INFO:     Started server process [270]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %%
# ================== INSTALL (uncomment in Colab) ==================
# !pip install fastapi uvicorn pyngrok nest_asyncio requests torch torchvision transformers ultralytics deepface opencv-python pillow

# ================== IMPORTS ==================
from fastapi import FastAPI, UploadFile, File, Request, HTTPException
from fastapi.staticfiles import StaticFiles
from fastapi.templating import Jinja2Templates
from fastapi.responses import HTMLResponse
from fastapi.middleware.cors import CORSMiddleware
import torch
import requests
import cv2
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
from ultralytics import YOLO
from deepface import DeepFace
import numpy as np
import collections
import os
import shutil
from pathlib import Path
import uvicorn
from pyngrok import ngrok
import nest_asyncio
import threading

# ================== FASTAPI INIT ==================
app = FastAPI()

# Allow CORS for frontend
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# ================== PATHS ==================
drive_path = "/content/drive/MyDrive/Project/NLP Project/Code/Project"
app.mount("/static", StaticFiles(directory=f"{drive_path}/static"), name="static")
templates = Jinja2Templates(directory=drive_path)

# ================== API KEYS ==================
MISTRAL_API_KEY = "8bhvT7fCsMFassdW44g8VUP2YxmaxlLZ"
MISTRAL_API_URL = "https://api.mistral.ai/v1/chat/completions"

# ================== MODELS ==================
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
blip_model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-large", torch_dtype=torch.float16
)
blip_device = "cuda" if torch.cuda.is_available() else "cpu"
blip_model.to(blip_device)

yolo_model_large = YOLO("/content/best.pt")
yolo_model_small = YOLO("/content/best.pt")

# Create uploads directory if not exists
os.makedirs(f"{drive_path}/static/uploads", exist_ok=True)

# ================== HELPERS (Mistral) ==================
def call_mistral(messages, temperature=0.7, model="mistral-small-latest"):
    headers = {"Authorization": f"Bearer {MISTRAL_API_KEY}", "Content-Type": "application/json"}
    data = {"model": model, "messages": messages, "temperature": temperature}
    try:
        response = requests.post(MISTRAL_API_URL, headers=headers, json=data)
        result = response.json()
        return result["choices"][0]["message"]["content"].strip()
    except Exception as e:
        print("Mistral API Error:", str(e))
        return "❌ Error from Mistral API."

def get_task_from_prompt(prompt: str):
    system_msg = (
        "You're a strict classifier. ONLY respond with one of the following exact words:\n"
        "image_captioning, scene_description, object_detection, object_counting, "
        "question_answering, emotion_detection, video_summarization, real_time_tracking.\n"
        "No explanation. No extra text."
    )
    return call_mistral(
        [{"role": "system", "content": system_msg}, {"role": "user", "content": prompt}],
        temperature=0,
    ).lower()

def get_small_talk_reply(prompt: str):
    return call_mistral(
        [{"role": "system", "content": "You're a helpful and friendly assistant."},
         {"role": "user", "content": prompt}],
        temperature=0.7
    )

def describe_caption_with_mistral(caption, objects):
    prompt = f"Describe the scene based on the following details:\nCaption: {caption}\nDetected Objects: {', '.join(objects)}"
    return call_mistral([{"role": "user", "content": prompt}], temperature=0.7)

# ================== TASK FUNCTIONS ==================
def caption_image(image_path):
    # Step 1: Generate raw caption from BLIP
    image = Image.open(image_path).convert("RGB")
    inputs = blip_processor(images=image, return_tensors="pt").to(blip_device, torch.float16)
    generated_ids = blip_model.generate(**inputs, max_new_tokens=60, num_beams=5)
    raw_caption = blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()

    # Step 2: Detect objects with YOLO
    objects = detect_objects(image_path)["objects"]

    # Step 3: Refine caption with Mistral
    prompt = (
        f"Here is a raw image caption: '{raw_caption}'.\n"
        f"Detected objects in the image: {', '.join(objects)}.\n"
        "Write a more accurate, detailed, and natural description of the scene."
    )
    better_caption = call_mistral([{"role": "user", "content": prompt}], temperature=0.7)

    return better_caption

def detect_objects(image_path):
    results = yolo_model_large(image_path)
    classes = results[0].names
    class_ids = results[0].boxes.cls.tolist()
    detected_objects = list(set(classes[int(cls_id)] for cls_id in class_ids))
    annotated_img = results[0].plot()

    annotated_path = f"{drive_path}/static/uploads/annotated_{Path(image_path).name}"
    Image.fromarray(annotated_img).save(annotated_path)

    return {
        "objects": detected_objects,
        "annotated_image": f"/static/uploads/annotated_{Path(image_path).name}"
    }

def count_objects(image_path):
    results = yolo_model_large(image_path)
    classes = results[0].names
    class_ids = results[0].boxes.cls.tolist()
    count_dict = {}
    for cls_id in class_ids:
        label = classes[int(cls_id)]
        count_dict[label] = count_dict.get(label, 0) + 1
    return count_dict

def detect_emotion_np(image_np):
    try:
        result = DeepFace.analyze(img_path=image_np, actions=["emotion"], enforce_detection=False)
        if isinstance(result, list):
            return [r["dominant_emotion"] for r in result]
        else:
            return [result["dominant_emotion"]]
    except:
        return []

# ================== API ENDPOINTS ==================
@app.post("/upload")
async def upload_file(file: UploadFile = File(...)):
    try:
        file_location = f"{drive_path}/static/uploads/{file.filename}"
        with open(file_location, "wb+") as file_object:
            shutil.copyfileobj(file.file, file_object)

        is_video = file.filename.lower().endswith((".mp4", ".avi", ".mov", ".mkv"))

        if not is_video:
            caption = caption_image(file_location)   # improved caption
            objects = detect_objects(file_location)
        else:
            caption = None
            objects = None

        return {
            "filename": file.filename,
            "filepath": f"/static/uploads/{file.filename}",
            "is_video": is_video,
            "caption": caption,
            "objects": objects,
        }
    except Exception as e:
        raise HTTPException(status_code=500, detail=str(e))

@app.post("/process")
async def process_request(request_data: dict):
    try:
        prompt = request_data.get("prompt", "").strip().lower()
        filepath = request_data.get("filepath", "")
        is_video = request_data.get("is_video", False)
        caption = request_data.get("caption", "")
        objects = request_data.get("objects", [])

        small_talk_phrases = ["hi", "hello", "hey", "yo", "howdy", "sup",
                             "good morning", "good evening", "what's up"]
        if prompt in small_talk_phrases:
            return {
                "response": "🤖 Hey there! 👋\n✨ I can help you with:\n- 🖼️ Captioning\n- 📷 Descriptions\n- 🔍 Detection\n- 🔢 Counting\n- 😊 Emotions\n- ❓ Q&A\n- 🎬 Summarization\n- 🔄 Tracking",
                "type": "small_talk",
            }

        task = get_task_from_prompt(prompt)

        if not task:
            return {
                "response": "🤖 I'm here for anything you need! Try asking me about an image or video task.",
                "type": "info",
            }

        if task in ["real_time_tracking", "video_summarization"] and not is_video:
            return {"response": "❌ This task requires a video file.", "type": "error"}
        elif task in ["image_captioning", "scene_description", "object_detection",
                      "object_counting", "emotion_detection", "question_answering"] and is_video:
            return {"response": "❌ This task requires an image file.", "type": "error"}

        full_path = f"{drive_path}{filepath}"
        result = {}
        if task == "image_captioning":
            result["response"] = f"🖼️ Caption: {caption}"
        elif task == "scene_description":
            description = describe_caption_with_mistral(caption, objects["objects"])
            result["response"] = f"📝 Scene Description: {description}"
        elif task == "object_detection":
            result["response"] = f"📦 Detected Objects: {objects['objects']}"
            result["annotated_image"] = objects["annotated_image"]
        elif task == "object_counting":
            count = count_objects(full_path)
            result["response"] = f"🔢 Object Count: {count}"
        elif task == "emotion_detection":
            img = cv2.imread(full_path)
            emotions = detect_emotion_np(img)
            result["response"] = f"😊 Detected Emotions: {collections.Counter(emotions)}"
        elif task == "question_answering":
            answer = get_small_talk_reply(f"Based on the image caption: '{caption}', answer: {prompt}")
            result["response"] = f"💡 Answer: {answer}"
        elif task == "real_time_tracking":
            result["response"] = "🔄 Real-time tracking not yet integrated."
        elif task == "video_summarization":
            result["response"] = "🎬 Video summarization not yet integrated."

        result["type"] = "task_response"
        return result

    except Exception as e:
        raise HTTPException(status_code=500, detail=str(e))

@app.get("/", response_class=HTMLResponse)
async def serve_frontend(request: Request):
    return templates.TemplateResponse("index.html", {"request": request})

# ================== RUN & STOP SERVER ==================
server_instance = None
thread = None

def run_server():
    global server_instance, thread
    ngrok.set_auth_token("33CkonDEthhmYxaMttQ5iCrBlS3_3Rs5hXMCgDBwLLgyzufYo")
    public_url = ngrok.connect(8000).public_url
    print(f"🚀 FastAPI server is live at: {public_url}")

    nest_asyncio.apply()
    config = uvicorn.Config(app, host="0.0.0.0", port=8000, log_level="info")
    server_instance = uvicorn.Server(config)

    thread = threading.Thread(target=server_instance.run, daemon=True)
    thread.start()

def stop_server():
    global server_instance
    if server_instance:
        server_instance.should_exit = True
        print("🛑 Server stopped.")

# ================== START ==================
run_server()   # starts server
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# 🚀 FastAPI server is live at: https://bloodily-unminimising-margorie.ngrok-free.dev
# INFO:     Started server process [270]
# INFO:     Waiting for application startup.

# %%
stop_server()  # stops server
# Out:
# 🛑 Server stopped.
